# %%
# %sql

-- Create a table named 'docs_text' within the 'rag' schema
CREATE OR REPLACE TABLE llmdb2.rag.docs_text (
    id BIGINT GENERATED BY DEFAULT AS IDENTITY,
    text STRING
)
tblproperties (delta.enableChangeDataFeed = true);;



-- Create a table named 'docs_load_tracker' within the 'rag' schema
CREATE OR REPLACE TABLE llmdb2.rag.docs_load_tracker (
    file_name STRING,
    load_timestamp TIMESTAMP
)
tblproperties (delta.enableChangeDataFeed = true);;
